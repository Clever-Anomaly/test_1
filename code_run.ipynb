# %%
# !git clone https://github.com/Clever-Anomaly/CUDA_at_Scale_Independent_Project
# Out:
# Cloning into 'CUDA_at_Scale_Independent_Project'...
# remote: Enumerating objects: 96, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 96 (delta 24), reused 96 (delta 24), pack-reused 0 (from 0)
# Receiving objects: 100% (96/96), 18.32 MiB | 15.32 MiB/s, done.
# Resolving deltas: 100% (24/24), done.

# %%
# !sudo apt-get update
# !sudo apt-get install libfreeimage-dev
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,008 kB]
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,835 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
# !export CUDA_PATH=/usr/local/cuda
# !export LD_LIBRARY_PATH=$CUDA_PATH/lib64:$LD_LIBRARY_PATH

# %%
# !nvcc --version
# !nvidia-smi
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0
# Thu Nov 27 21:53:26 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# ...

# %%
# !ls
# Out:
# CUDA_at_Scale_Independent_Project  sample_data

# %%
cd CUDA_at_Scale_Independent_Project/edgeDetectionNPP/
# Out:
# /content/CUDA_at_Scale_Independent_Project/edgeDetectionNPP

# %%
# !chmod +x build.sh

# %%
# !./build.sh
# Out:
# ...
# Building Edge Detection NPP
# ...
#
# CUDA Path: /usr/local/cuda
# Building edgeDetectionNPP...
#
#
# ...
# ✓ Build Successful!
# ...
#
# Executable: edgeDetectionNPP
# Size: 64K
#
# Usage:
#   ./edgeDetectionNPP                    # Use default Lena.pgm
#   ./edgeDetectionNPP --input=image.pgm  # Custom image

# %%
# !mkdir output

# %%
# !./edgeDetectionNPP --input=th.jpeg
# Out:
# ./edgeDetectionNPP Starting...
#
# Supports: JPG, PNG, BMP, PGM and other image formats
# Automatically converts color images to grayscale
#
# GPU Device 0: "Turing" with compute capability 7.5
#
# NPP Library Version 12.3.0
#   CUDA Driver  Version: 12.4
#   CUDA Runtime Version: 12.5
#   Device 0: <          Turing >, Compute SM 7.5 detected
# Loading image: input/th.jpeg
#   Image format: JPEG
#   Image size: 474x315
#   Bits per pixel: 24
#   Converting to grayscale...
# ✓ Image loaded successfully
#
# Applying Sobel edge detection...
#   Computing horizontal edges...
#   Computing vertical edges...
#
# Saving results...
#   ✓ Saved: output/th_edges_horizontal.png
#   ✓ Saved: output/th_edges_vertical.png
#
# ...
# Edge detection complete!
# ...
#
# Output files:
#   • Horizontal edges (vertical lines): output/th_edges_horizontal.png
#   • Vertical edges (horizontal lines): output/th_edges_vertical.png
#
# Tip: PNG files can be viewed directly in any image viewer!

# %%
# !./edgeDetectionNPP --input=test1.jpg
# Out:
# ./edgeDetectionNPP Starting...
#
# Supports: JPG, PNG, BMP, PGM and other image formats
# Automatically converts color images to grayscale
#
# GPU Device 0: "Turing" with compute capability 7.5
#
# NPP Library Version 12.3.0
#   CUDA Driver  Version: 12.4
#   CUDA Runtime Version: 12.5
#   Device 0: <          Turing >, Compute SM 7.5 detected
# Loading image: input/test1.jpg
#   Image format: JPEG
#   Image size: 736x1104
#   Bits per pixel: 24
#   Converting to grayscale...
# ✓ Image loaded successfully
#
# Applying Sobel edge detection...
#   Computing horizontal edges...
#   Computing vertical edges...
#
# Saving results...
#   ✓ Saved: output/test1_edges_horizontal.png
#   ✓ Saved: output/test1_edges_vertical.png
#
# ...
# Edge detection complete!
# ...
#
# Output files:
#   • Horizontal edges (vertical lines): output/test1_edges_horizontal.png
#   • Vertical edges (horizontal lines): output/test1_edges_vertical.png
#
# Tip: PNG files can be viewed directly in any image viewer!
